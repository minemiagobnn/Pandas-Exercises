# %% [markdown]
# # US - Baby Names

# %% [markdown]
# ### Introduction:
#
# We are going to use a subset of [US Baby Names](https://www.kaggle.com/kaggle/us-baby-names) from Kaggle.
# In the file it will be names from 2004 until 2014
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Baby_Names_right.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called baby_names.

# %%
baby_names = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/US_Baby_Names_right.csv')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
display(baby_names.head(10))
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %% [markdown]
# ### Step 5. Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names.drop(['Unnamed: 0', 'Id'], axis=1, inplace=True)
display(baby_names.head())
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %% [markdown]
# ### Step 6. Is there more male or female names in the dataset?

# %%
gender_counts = baby_names['Gender'].value_counts()
display(gender_counts)
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %% [markdown]
# ### Step 7. Group the dataset by name and assign to names

# %%
names = baby_names.groupby('Name')['Count'].sum()
display(names.head())
# Out:
# Name
# Aaban        12
# Aadan        23
# Aadarsh       5
# Aaden      3426
# Aadhav        6
# Name: Count, dtype: int64

# %% [markdown]
# ### Step 8. How many different names exist in the dataset?

# %%
num_unique_names = len(names)
print(f"There are {num_unique_names} different names in the dataset.")
# Out:
# There are 17632 different names in the dataset.

# %% [markdown]
# ### Step 9. What is the name with most occurrences?

# %%
name_with_most_occurrences = names.idxmax()
max_occurrences_count = names.max()
print(f"The name with the most occurrences is '{name_with_most_occurrences}' with a count of {max_occurrences_count}.")
# Out:
# The name with the most occurrences is 'Jacob' with a count of 242874.

# %% [markdown]
# ### Step 10. How many different names have the least occurrences?

# %%
min_occurrences = names.min()
names_with_least_occurrences = names[names == min_occurrences]
num_names_with_least_occurrences = len(names_with_least_occurrences)
print(f"There are {num_names_with_least_occurrences} different names with the least occurrences (count: {min_occurrences}).")
# Out:
# There are 2578 different names with the least occurrences (count: 5).

# %% [markdown]
# ### Step 11. What is the median name occurrence?

# %%
median_occurrence = names.median()
print(f"The median name occurrence is {median_occurrence}.")
# Out:
# The median name occurrence is 49.0.

# %% [markdown]
# ### Step 12. What is the standard deviation of names?

# %%
std_deviation = names.std()
print(f"The standard deviation of name occurrences is {std_deviation}.")
# Out:
# The standard deviation of name occurrences is 11006.069467891111.

# %% [markdown]
# ### Step 13. Get a summary with the mean, min, max, std and quartiles.

# %%
name_summary = names.describe()
display(name_summary)
# Out:
# count     17632.000000
# mean       2008.932169
# std       11006.069468
# min           5.000000
# 25%          11.000000
# 50%          49.000000
# 75%         337.000000
# max      242874.000000
# Name: Count, dtype: float64
